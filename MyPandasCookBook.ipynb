# %% [markdown]
# # Pandas Cookbook

# %% [markdown]
# ## First a word on filepaths : Absolute vs Relative
#
# - The Absolute path is the full path to some place on your computer.
# - The Relative path is the path to some file with respect to your current working directory (PWD).
#
# For example:-
#
# Absolute path: C:/users/admin/docs/stuff.txt  <-- use this always, don't be lazy!!!
#
# If my PWD is C:/users/admin/, then the relative path to stuff.txt would be: docs/stuff.txt

# %% [markdown]
# ## Loading files

# %%
import pandas as pd
import xlrd
from datetime import datetime

'''Excel Files'''
df_excel = pd.read_excel(r'C:\Users\Burudani\Documents\mainPythonFolder_v1\SpreadsheetFiles\Coffee_v1.xlsx',
sheet_name='Coffee')
# Specifying data types
df_excel = pd.read_excel(r'C:\Users\Burudani\Documents\mainPythonFolder_v1\SpreadsheetFiles\Coffee_v1.xlsx',
sheet_name='Coffee',
dtype = {"image": str,
         "freq": float})


'''CSV Files'''
date_cols = ['date_cc'] # Specifying columns to be treated as datetimes, and passing it to the pandas 
df_csv = pd.read_csv (r'C:\Users\Burudani\Documents\mainPythonFolder_v1\SpreadsheetFiles\climate_change.csv',parse_dates=date_cols,
dtype={"co2": float,
"relative_temp": float})

# Specifying index column via column location
medals = pd.read_csv(r'C:\Users\Burudani\Documents\mainPythonFolder_v1\SpreadsheetFiles\medals_by_country_2016.csv',index_col = 0)  

# Specifying index column via column name

summer2016 = pd.read_csv(r'C:\Users\Burudani\Documents\mainPythonFolder_v1\SpreadsheetFiles\summer2016.csv',index_col = 'ID')  

# Creating a new Df cleanly using 
slicedDf = summer2016.loc[(summer2016["Sex"] == "M" ) & (summer2016["Sport"] == "Gymnastics" ), ["Name","Sex","Age","Sport"]]
slicedDf
# Out:
#                                     Name Sex   Age       Sport
# ID
# 455          Denis Mikhaylovich Ablyazin   M  24.0  Gymnastics
# 455          Denis Mikhaylovich Ablyazin   M  24.0  Gymnastics
# 455          Denis Mikhaylovich Ablyazin   M  24.0  Gymnastics
# 9829          David Sagitovich Belyavsky   M  24.0  Gymnastics
# 9829          David Sagitovich Belyavsky   M  24.0  Gymnastics
# 27572                         Deng Shudi   M  24.0  Gymnastics
# 45219                    Fabian Hambchen   M  28.0  Gymnastics
# 51457               Diego Matias Hyplito   M  30.0  Gymnastics
# 57997                        Ryohei Kato   M  22.0  Gymnastics
# 64787        Nikolay Yulyevich Kuksenkov   M  27.0  Gymnastics
# 69285        Danell Johan Leyva Gonzalez   M  24.0  Gymnastics
# 69285        Danell Johan Leyva Gonzalez   M  24.0  Gymnastics
# 69955                        Lin Chaopan   M  20.0  Gymnastics
# 70677                           Liu Yang   M  21.0  Gymnastics
# 75010        Arthur Nory Oyakawa Mariano   M  22.0  Gymnastics
# 84014   Alexander Michael "Alex" Naddour   M  25.0  Gymnastics
# 84138       Nikita Vladimirovich Nagorny   M  19.0  Gymnastics
# 94094             Eleftherios Petrounias   M  25.0  Gymnastics
# 100351                       Ri Se-Gwang   M  31.0  Gymnastics
# 109869                      Kenzo Shirai   M  19.0  Gymnastics
# 109869                      Kenzo Shirai   M  19.0  Gymnastics
# 112342               Louis Antoine Smith   M  27.0  Gymnastics
# 115758      Ivan Alekseyevich Stretovich   M  19.0  Gymnastics
# 118359                     Yusuke Tanaka   M  26.0  Gymnastics
# 123056                    Kohei Uchimura   M  27.0  Gymnastics
# 123056                    Kohei Uchimura   M  27.0  Gymnastics
# 126096         Oleh Yuriyovych Verniaiev   M  22.0  Gymnastics
# 126096         Oleh Yuriyovych Verniaiev   M  22.0  Gymnastics
# 130071               Max Antony Whitlock   M  23.0  Gymnastics
# 130071               Max Antony Whitlock   M  23.0  Gymnastics
# 130071               Max Antony Whitlock   M  23.0  Gymnastics
# 130874                       Nile Wilson   M  20.0  Gymnastics
# 132340                     Koji Yamamuro   M  27.0  Gymnastics
# 133174                           You Hao   M  24.0  Gymnastics
# 133931          Arthur Nabarrete Zanetti   M  26.0  Gymnastics
# 134433                   Zhang Chenglong   M  27.0  Gymnastics
